# %% [markdown]
# ## Placeholder map for Atlas
# **Function**      : Plot placeholder map in a uniform way as other maps for Atlas<br>
# **Author          : Team BETA**<br>
# **First Built**   : 2021.09.27<br>
# **Last Update     : 2021.09.27**<br>
# **Library**       : os, numpy, netcdf4, matplotlib, cartopy<br>
# **Description**   : This notebook serves to generate a placeholder for Atlas page.<br>
# **Return Values   : png files**<br>
# **Note**          : All the maps are generated in a uniform way.<br>

# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ### Path
# Specify the path to the dataset and the place to save the outputs. <br>

# %%
# please specify data path
datapath = '/mnt/d/NLeSC/BETA/EUCP/Atlas'
# please specify output path
output_path = '../static'
os.makedirs(output_path, exist_ok = True)

# %% [markdown]
# ### Extract data
# Extract weather/climate data from given netCDF files.

# %%
# plot figure
fig = plt.figure(figsize=(12.8,9.6))
axes = fig.gca()
axes.axes.get_xaxis().set_visible(False)
axes.axes.get_yaxis().set_visible(False)
textstr = "No map is available with the requested combination of parameters"
# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='white', edgecolor='white', alpha=0.2)

# place a text box in upper left in axes coords
plt.text(0.1, 0.5, textstr, fontsize=20,
        verticalalignment='top', bbox=props)
plt.tight_layout()
plt.show()
fig.savefig(Path(output_path,"placeholder.png"),dpi=150)
